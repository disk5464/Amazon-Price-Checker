# %%
# %pip install bs4
# %pip install requests

import requests
from bs4 import BeautifulSoup #BeautifulSoup is used to parse the HTML of the comic pages
import json
# Out:
# Requirement already satisfied: bs4 in c:\users\scoob\appdata\local\programs\python\python310\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\scoob\appdata\local\programs\python\python310\lib\site-packages (from bs4) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\scoob\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->bs4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\scoob\appdata\roaming\python\python310\site-packages (from beautifulsoup4->bs4) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in c:\users\scoob\appdata\local\programs\python\python310\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\scoob\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\scoob\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\scoob\appdata\local\programs\python\python310\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\scoob\appdata\local\programs\python\python310\lib\site-packages (from requests) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
page = requests.get("https://www.amazon.com/dp/B08MWBFMX5")
#print(page)
soup = BeautifulSoup(page.text, 'html.parser')
print(soup)

# %%
URL = "https://www.amazon.com/dp/B08MWBFMX5"
page = requests.get(URL)
print(page.text)

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.amazon.com/dp/B08MWBFMX5"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
thumbnail = soup.find(id="imgTagWrapperId")
print(thumbnail.prettify())
# Out:
# <div class="imgTagWrapper" id="imgTagWrapperId" role="button" tabindex="0">
#  <img alt="GHOST Energy Drink - 12-Pack, Sour Patch Kids Redberry, 16oz - Energy &amp;amp; Focus &amp;amp; No Artificial Colors - 200mg of Natural Caffeine, L-Carnitine &amp;amp; Taurine - Gluten-Free &amp;amp; Vegan" class="a-dynamic-image a-stretch-horizontal" data-a-dynamic-image='{"https://m.media-amazon.com/images/I/81in7DvdE+L._SX425_PIbundle-12,TopRight,0,0_AA425SH20_.jpg":[425,425],"https://m.media-amazon.com/images/I/81in7DvdE+L._SX466_PIbundle-12,TopRight,0,0_AA466SH20_.jpg":[466,466],"https://m.media-amazon.com/images/I/81in7DvdE+L._SX569_PIbundle-12,TopRight,0,0_AA569SH20_.jpg":[569,569],"https://m.media-amazon.com/images/I/81in7DvdE+L._SX679_PIbundle-12,TopRight,0,0_AA679SH20_.jpg":[679,679],"https://m.media-amazon.com/images/I/81in7DvdE+L._SX342_PIbundle-12,TopRight,0,0_AA342SH20_.jpg":[342,342],"https://m.media-amazon.com/images/I/81in7DvdE+L._SX385_PIbundle-12,TopRight,0,0_AA385SH20_.jpg":[385,385],"https://m.media-amazon.com/images/I/81in7DvdE+L._SX522_PIbundle-12,TopRight,0,0_AA522SH20_.jpg":[522,522]}' data-a-image-name="landingImage" data-old-hires="https://m.media-amazon.com/images/I/81in7DvdE+L._SL1500_.jpg" id="landingImage" onload="markFeatureRenderForImageBlock(); this.onload='';setCSMReq('af');if(typeof addlongPoleTag === 'function'){ addlongPoleTag('af','desktop-image-atf-marker');};setCSMReq('cf')" src="https://m.media-amazon.com/images/I/518zH3I3N8L._SY300_SX300_QL70_ML2_.jpg" style="max-width:679px;max-height:679px;"/>
# </div>

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.amazon.com/dp/B08MWBFMX5"

page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

img = soup.find("img", id="landingImage")
#alt_text = img.get("alt") if img else None
flavor = (img.get("alt") if img else None).split(",")[]

print(flavor)

pic = img.get("src") if img else None
print(pic)
# Out:
#  Sour Patch Kids Redberry
# https://m.media-amazon.com/images/I/518zH3I3N8L._SY300_SX300_QL70_ML2_.jpg

# %%
#Import the libaries
import requests
from bs4 import BeautifulSoup

#Get the url, get the HTML page, pass it though Beautiful Soup
allASINs = ["B0DF1L929C", "B0GFC458B3", "B0FJVHTYK3", "B09YGL4BCM", "B08MWBFMX5", "B09YG6LN3W", "B0DQ6ZFD98", "B0BHKR7Z4L", "B08MW9LXK7"]
for ASIN in allASINs:
    
    URL = "https://www.amazon.com/dp/"+ASIN
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")

    #Grab the item's main image section and extract the JPG and its associated meta data 
    MainImageSection = soup.find("img", id="landingImage")
    #Create a vairable for the JPG's URL and a variable for the JPG's name, which is the product name.
    thumbnail = MainImageSection.get("src") if MainImageSection else None
    
    #Grab the item's main title, extract the whole string, then clean it up and send it to the flavor variable
    titleSoup = soup.find("span", id="productTitle")
    RawflavorString = titleSoup.get_text("span") if titleSoup else None
    flavor = RawflavorString.split(",")[1].removeprefix(" ")
    
    #Get the price data section, extract the price HTML, clean it up, save it to a variable
    price_span = soup.select_one(
        "#apex_offerDisplay_desktop span.a-price span.a-offscreen"
    )
    
    priceSection = price_span.get_text(strip=True) if price_span else None
    #priceSection = soup.select_one("#corePriceDisplay_desktop_feature_div span.aok-offscreen")
    #priceHTML = priceSection.text.strip() if priceSection else None
    

    print(flavor)
    print(thumbnail)
    print(priceSection)
    print("##############################################################")

# %%
#Import the libaries
import requests
from bs4 import BeautifulSoup

#Make a list of the items we want to search
allASINs = ["B0DF1L929C", "B0GFC458B3", "B0FJVHTYK3", "B09YGL4BCM",
            "B08MWBFMX5", "B09YG6LN3W", "B0DQ6ZFD98", "B0BHKR7Z4L", "B08MW9LXK7"]

#Create a new session variable and add in some headers so that the requests look more like a browser made them
session = requests.Session()
session.headers.update({
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8",
    "Upgrade-Insecure-Requests": "1",
})

#Define a function that takes in the soup object and a list of possible HTML elements. Check each one to see if they have any text in them. Return any found text
def get_first_non_empty_text(html_soup, css_selectors):
    for selector in css_selectors:
        #Select just the html from the entire element
        matched_element = html_soup.select_one(selector)

        #If it's empty continue to the next HTML element
        if matched_element is None:
            continue

        extracted_text = matched_element.get_text(strip=True)

        if extracted_text:
            return extracted_text

    return None

for ASIN in allASINs:
    URL = f"https://www.amazon.com/dp/{ASIN}"
    r = session.get(URL, timeout=20)
    soup = BeautifulSoup(r.text, "html.parser")

    # Quick block detection
    lower = r.text.lower()
    blocked = any(k in lower for k in ["robot check", "captcha", "/errors/validatecaptcha", "type the characters"])
    if blocked:
        print(ASIN, "BLOCKED (captcha/robot page)")
        print("##############################################################")
        continue

    # Main image
    main_img = soup.find("img", id="landingImage")
    thumbnail = main_img.get("src") if main_img else None

    # Title
    title_el = soup.find("span", id="productTitle")
    title = title_el.get_text(strip=True) if title_el else None

    # Your current flavor parsing can throw if there's no comma; make it safe:
    flavor = None
    if title and "," in title:
        parts = [p.strip() for p in title.split(",")]
        flavor = parts[1] if len(parts) > 1 else None

    # Price (try the apex buybox first, then core price display, then any a-offscreen)
    price_css_selectors = [
        "#apex_offerDisplay_desktop span.a-price span.a-offscreen",
        "#corePriceDisplay_desktop_feature_div span.aok-offscreen",
        "span.a-price span.a-offscreen",
    ]

    price = get_first_non_empty_text(soup, price_css_selectors).replace("$","")
    

    print("ASIN:", ASIN)
    print("Flavor:", flavor)
    print("Thumbnail:", thumbnail)
    print("Price:", price)
    print("##############################################################")
# Out:
# ASIN: B0DF1L929C
# Flavor: Welch's Grape
# Thumbnail: https://m.media-amazon.com/images/I/51kyd4qhG-L._SY300_SX300_QL70_FMwebp_.jpg
# Price: 29.99
# ##############################################################
# ASIN: B0GFC458B3
# Flavor: Blue Raspberry
# Thumbnail: https://m.media-amazon.com/images/I/51QesRHR5aL._SY300_SX300_QL70_FMwebp_.jpg
# Price: 29.99
# ##############################################################
# ASIN: B0FJVHTYK3
# Flavor: Original
# Thumbnail: https://m.media-amazon.com/images/I/41686w4iYPL._SY300_SX300_QL70_FMwebp_.jpg
# Price: 29.99
# ##############################################################
# ASIN: B09YGL4BCM
# Flavor: Sour Patch Kids Blue Raspberry
# Thumbnail: https://m.media-amazon.com/images/I/51CllWWvvNL._SY300_SX300_QL70_FMwebp_.jpg
# Price: 29.76
# ##############################################################
# ASIN: B08MWBFMX5
# Flavor: Sour Patch Kids Redberry
# Thumbnail: https://m.media-amazon.com/images/I/518zH3I3N8L._SY300_SX300_QL70_FMwebp_.jpg
# Price: 23.81
# ##############################################################
# ASIN: B09YG6LN3W
# Flavor: Swedish Fish
# Thumbnail: https://m.media-amazon.com/images/I/51UcjWy8NAL._SY300_SX300_QL70_FMwebp_.jpg
# Price: 29.76
# ##############################################################
# ASIN: B0DQ6ZFD98
# Flavor: Electric Limeade
# Thumbnail: https://m.media-amazon.com/images/I/51IPqYKWxXL._SY300_SX300_QL70_FMwebp_.jpg
# Price: 3.00
# ##############################################################
# ASIN: B0BHKR7Z4L
# Flavor: Warheads Sour Green Apple
# Thumbnail: https://m.media-amazon.com/images/I/51TH2kdiLNL._SY300_SX300_QL70_FMwebp_.jpg
# Price: 29.99
# ##############################################################
# ASIN: B08MW9LXK7
# Flavor: Warheads Sour Watermelon
# Thumbnail: https://m.media-amazon.com/images/I/51ZilckBR7L._SY300_SX300_QL70_FMwebp_.jpg
# Price: 29.99
# ##############################################################

# %%
#The above code works just fine and was merged into v2.0 and later into 2.1. The next set of code was to figurout how to handle the sold out issue

# %%
#Import the libaries
import requests, time
from bs4 import BeautifulSoup

#Make a list of the items we want to search
allASINs = ["B0DF1L929C", "B0GFC458B3", "B0FJVHTYK3", "B09YGL4BCM","B08MWBFMX5", "B09YG6LN3W", "B0DQ6ZFD98", "B0BHKR7Z4L", "B08MW9LXK7"]
#allASINs = ["B0DQ6ZFD98"]
#Create a new session variable and add in some headers so that the requests look more like a browser made them
session = requests.Session()
session.headers.update({
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8",
    "Upgrade-Insecure-Requests": "1",
})

#Define a function that takes in the soup object and a list of possible HTML elements. Check each one to see if they have any text in them. Return any found text
def get_first_non_empty_text(html_soup, css_selectors):
    for selector in css_selectors:
        #Select just the html from the entire element
        matched_element = html_soup.select_one(selector)

        #If it's empty continue to the next HTML element
        if matched_element is None:
            continue

        extracted_text = matched_element.get_text(strip=True)
        print(extracted_text)
        if extracted_text:
            return extracted_text

    return None

#For each item we are going to search
for ASIN in allASINs:
    #Reset the blocked variable. This is so that the script will retry untill it becomes unblocked
    currentlyblocked = True
    
    #While the search was blocked
    while currentlyblocked == True :
        URL = f"https://www.amazon.com/dp/{ASIN}"
        r = session.get(URL, timeout=20)
        soup = BeautifulSoup(r.text, "html.parser")

        # Quick block detection
        lower = r.text.lower()
        blocked = any(k in lower for k in ["robot check", "captcha", "/errors/validatecaptcha", "type the characters"])

        #If the script is currently blocked wait 2 seconds then rerun that item's search
        if blocked:
            print(ASIN, "BLOCKED (captcha/robot page)")
            print("##############################################################")
            currentlyblocked = True
            time.sleep(2)
            continue
        else: 
            #Set the block variable to False so we will move onto the next item after this pass since we are not blocked
            currentlyblocked = False

            #Scrap the main item image and save it to a variable
            main_img = soup.find("img", id="landingImage")
            thumbnail = main_img.get("src") if main_img else None

            #Get the item's main title and save it to a variable. This variable has a bunch of junk in it and needs to be cleaned "GHOST Energy Drink - 12-Pack, Welch's Grape, 16oz Cans Blah blah blah"
            title_el = soup.find("span", id="productTitle")
            title = title_el.get_text(strip=True) if title_el else None

            #Take the title, split it on the commas, then select the second item in that list, which is just the flavor (Welch's Grape). Save that to an output variable
            flavor = None
            if title and "," in title:
                parts = [p.strip() for p in title.split(",")]
                flavor = parts[1] if len(parts) > 1 else None

            #There are 3 different places where the price can spawn in the HTML depending on how the page loads. Set an array of each localtion.
            price_css_selectors = [
                "#outOfStock span.a-color-price.a-text-bold",
                "#apex_offerDisplay_desktop span.a-price span.a-offscreen",
                "#corePriceDisplay_desktop_feature_div span.aok-offscreen",
                "span.a-price span.a-offscreen",
            ]

            #Feed that array into the function that finds out if the price is present. Return that value, remove the dollar sign, save it to an output variable
            price = get_first_non_empty_text(soup, price_css_selectors).replace("$","")

            #print("ASIN:", ASIN)
            #print("Flavor:", flavor)
            #print("Thumbnail:", thumbnail)
            #print("Price:", price)
            #print("##############################################################")
# Out:
# $29.99
# $29.99
# $29.99
# $29.76
# $23.81
# $29.76
# Currently unavailable.
# $29.99
# $29.99

# %%
#%pip install streamlit
import streamlit as st
import time

allASINs = ["B0DF1L929C", "B0GFC458B3", "B0FJVHTYK3", "B09YGL4BCM","B08MWBFMX5", "B09YG6LN3W", "B0DQ6ZFD98", "B0BHKR7Z4L", "B08MW9LXK7"]

progressIncrement = int(100 / len(allASINs))
print(progressIncrement)
progress_text = "Gathering pricing info. Please wait."
my_bar = st.progress(0, text=progress_text)

for percent_complete in range(100):
    time.sleep(1)
    my_bar.progress(percent_complete + progressIncrement, text=progress_text)

time.sleep(1)
my_bar.empty()
# Out:
# 2026-02-04 14:13:44.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 11
# 2026-02-04 14:13:44.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:44.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.455 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.455 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-04 14:13:45.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# StreamlitAPIException                     Traceback (most recent call last)
# Cell In[23], line 14
#      12 for percent_complete in range(100):
#      13     time.sleep(0.01)
# ---> 14     my_bar.progress(percent_complete + progressIncrement, text=progress_text)
#      16 time.sleep(1)
#      17 my_bar.empty()
#
# File c:\Users\scoob\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\elements\progress.py:159, in ProgressMixin.progress(self, value, text, width)
#     157 # TODO: standardize numerical type checking across st.* functions.
#     158 progress_proto = ProgressProto()
# --> 159 progress_proto.value = _get_value(value)
#     160 text = _get_text(text)
#     161 if text is not None:
#
# File c:\Users\scoob\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\elements\progress.py:65, in _get_value(value)
#      63     if 0 <= value <= 100:
#      64         return value
# ---> 65     raise StreamlitAPIException(
#      66         f"Progress Value has invalid value [0, 100]: {value}"
#      67     )
#      69 if isinstance(value, float):
#      70     if _check_float_between(value, low=0.0, high=1.0):
#
# StreamlitAPIException: Progress Value has invalid value [0, 100]: 101
